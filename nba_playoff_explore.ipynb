# %%
import pandas as pd
import numpy as np
import os
import wranglerer as wr
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = (6,4)
plt.rcParams["font.size"] = 10
from sklearn.model_selection import train_test_split
import scipy.stats as stats

# %%
df_raw = pd.read_csv('nba.csv')

# %%
df_raw.head()
# Out:
#                   team  fg_pct  opp_fg_pct  three_pt_pct  opp_three_pt_pct  \
# 0       Atlanta Hawks*   0.464       0.458         0.173             0.251
# 1      Boston Celtics*   0.490       0.470         0.384             0.286
# 2        Chicago Bulls   0.484       0.496         0.255             0.271
# 3  Cleveland Cavaliers   0.474       0.501         0.193             0.291
# 4       Denver Nuggets   0.463       0.492         0.325             0.327
#
#    ft_pct  rebounds  opp_rebounds  assists  steals  opp_steals  \
# 0   0.771      46.3          44.2     23.5     9.6         8.4
# 1   0.779      43.3          40.7     25.9     9.5         8.1
# 2   0.779      42.4          41.5     25.5     8.3        10.0
# 3   0.772      42.0          44.1     24.0     8.7         8.1
# 4   0.737      44.7          44.1     24.2     8.7         9.5
#
#    trnovrs_commited    pts  opp_pts  opp_fouls  prev_season  playoffs
# ...

# %%
df_raw.team[0]
# Out:
# 'Atlanta Hawks*'

# %%
df_raw['team'] = df_raw.team.str.replace('*','')
# Out:
# /var/folders/ty/2pnn6wsj06n_glzjgbmxzlkw0000gn/T/ipykernel_1327/728178884.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_raw['team'] = df_raw.team.str.replace('*','')

# %%
df_raw.head()
# Out:
#                   team  fg_pct  opp_fg_pct  three_pt_pct  opp_three_pt_pct  \
# 0        Atlanta Hawks   0.464       0.458         0.173             0.251
# 1       Boston Celtics   0.490       0.470         0.384             0.286
# 2        Chicago Bulls   0.484       0.496         0.255             0.271
# 3  Cleveland Cavaliers   0.474       0.501         0.193             0.291
# 4       Denver Nuggets   0.463       0.492         0.325             0.327
#
#    ft_pct  rebounds  opp_rebounds  assists  steals  opp_steals  \
# 0   0.771      46.3          44.2     23.5     9.6         8.4
# 1   0.779      43.3          40.7     25.9     9.5         8.1
# 2   0.779      42.4          41.5     25.5     8.3        10.0
# 3   0.772      42.0          44.1     24.0     8.7         8.1
# 4   0.737      44.7          44.1     24.2     8.7         9.5
#
#    trnovrs_commited    pts  opp_pts  opp_fouls  prev_season  playoffs
# ...

# %%
df = df_sans_teams = df_raw.drop(columns='team')

# %%
df
# Out:
#       fg_pct  opp_fg_pct  three_pt_pct  opp_three_pt_pct  ft_pct  rebounds  \
# 0      0.464       0.458         0.173             0.251   0.771      46.3
# 1      0.490       0.470         0.384             0.286   0.779      43.3
# 2      0.484       0.496         0.255             0.271   0.779      42.4
# 3      0.474       0.501         0.193             0.291   0.772      42.0
# 4      0.463       0.492         0.325             0.327   0.737      44.7
# ...      ...         ...           ...               ...     ...       ...
# 1219   0.494       0.492         0.369             0.373   0.790      42.0
# 1220   0.465       0.507         0.345             0.391   0.743      42.6
# 1221   0.459       0.491         0.335             0.374   0.784      44.0
# 1222   0.473       0.473         0.353             0.361   0.786      45.4
# 1223   0.485       0.473         0.356             0.366   0.785      44.1
#
# ...

# %%
df[(df['playoffs'] == 1) & (df['prev_season'] == 1)]
# Out:
#       fg_pct  opp_fg_pct  three_pt_pct  opp_three_pt_pct  ft_pct  rebounds  \
# 0      0.464       0.458         0.173             0.251   0.771      46.3
# 7      0.480       0.496         0.274             0.270   0.766      43.0
# 9      0.478       0.476         0.219             0.238   0.743      42.5
# 10     0.529       0.470         0.200             0.285   0.775      43.4
# 14     0.492       0.455         0.216             0.271   0.772      44.8
# ...      ...         ...           ...               ...     ...       ...
# 1211   0.490       0.471         0.365             0.369   0.755      41.1
# 1212   0.480       0.472         0.364             0.339   0.793      43.7
# 1216   0.487       0.473         0.387             0.348   0.835      41.8
# 1217   0.467       0.466         0.374             0.357   0.793      44.8
# 1221   0.459       0.491         0.335             0.374   0.784      44.0
#
# ...

# %%
#wr.summarize(df)

# %%
wr.get_hist_better(df)

# %%
wr.get_upper_outliers(df.opp_steals).sort_values(ascending=False).head(12)
# Out:
# 512    0.9
# 219    0.6
# 478    0.3
# 350    0.2
# 507    0.1
# 217    0.1
# 430    0.1
# 349    0.1
# 813    0.0
# 812    0.0
# 811    0.0
# 820    0.0
# Name: opp_steals, dtype: float64

# %%
wr.get_lower_outliers(df.pts,k=1.5).sort_values(ascending=False).head(9)
# Out:
# 601    3.2
# 483    3.0
# 776    1.8
# 787    1.5
# 781    1.2
# 512    1.2
# 785    0.3
# 866    0.2
# 814    0.0
# Name: pts, dtype: float64

# %%
df.pts.sort_values().head(9)
# Out:
# 601    92.2
# 483    92.4
# 776    93.6
# 787    93.9
# 781    94.2
# 512    94.2
# 785    95.1
# 866    95.2
# 976    95.5
# Name: pts, dtype: float64

# %%
train, validate, test = wr.split_data(df)

# %%
train.shape, validate.shape, test.shape
# Out:
# ((732, 16), (271, 16), (221, 16))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fg_pct            1224 non-null   float64
#  1   opp_fg_pct        1224 non-null   float64
#  2   three_pt_pct      1224 non-null   float64
#  3   opp_three_pt_pct  1224 non-null   float64
#  4   ft_pct            1224 non-null   float64
#  5   rebounds          1224 non-null   float64
#  6   opp_rebounds      1224 non-null   float64
#  7   assists           1224 non-null   float64
#  8   steals            1224 non-null   float64
#  9   opp_steals        1224 non-null   float64
#  10  trnovrs_commited  1224 non-null   float64
#  11  pts               1224 non-null   float64
#  12  opp_pts           1224 non-null   float64
#  13  opp_fouls         1224 non-null   float64
#  14  prev_season       1224 non-null   int64
#  15  playoffs          1224 non-null   int64
# ...

# %%
sns.catplot(data=train, x='playoffs', y='opp_pts',hue='playoffs',order=[1,0])
plt.xticks(ticks=[0,1],labels=['YES','NO'])
# plt.xlabel('playoffs')
# plt.ylabel('opp_pts')
plt.legend(labels=['YES','NO'],loc='lower left', bbox_to_anchor=(.9, .8))
plt.show()

# %% [markdown]
# # MEAN opp_points of Playoff teams vs MEAN opp_points of NON-Playoff teams
# ## Does a statistically significant difference exist between mean opp_points for playoff teams and that of
# ## non-playoff teams?
# ### T-Test 2-sample, 2-tail
#
# ### Hypothesis
#
# - ${H_0}$: No statistically significant difference exists between mean opp_points for playoff teams and that of non-playoff teams.
# - ${H_a}$: A statistically significant difference exists between mean opp_points for playoff teams and that onon-playoff teams.
#
# #### Two-tailed, Two-Sample T-Test ANY DIFF in mean between the two means

# %%
α = 0.05
opp_pts_playoff_values = train[train.playoffs == 1].opp_pts
opp_pts_nonplayoff_values = train[train.playoffs == 0].opp_pts
t, p = stats.ttest_ind(opp_pts_playoff_values,opp_pts_nonplayoff_values,equal_var=True)
print(t,p,α)
print(f'p = {p:e}')
# Out:
# -12.563677135487316 6.487650893466323e-33 0.05
# p = 6.487651e-33

# %% [markdown]
# # MEAN Turnovers_comm of Playoff teams vs MEAN Turnovers_comm of NON-Playoff teams
# ## Does a statistically significant difference exist between mean Turnovers_comm for playoff teams and that of
# ## non-playoff teams?
# ### T-Test 2-sample, 2-tail
#
# ### Hypothesis
#
# - ${H_0}$: No statistically significant difference exists between mean Turnovers_comm for playoff teams and that of non-playoff teams.
# - ${H_a}$: A statistically significant difference exists between mean turnovers_comm for playoff teams and that onon-playoff teams.
#
# #### Two-tailed, Two-Sample T-Test ANY DIFF in mean between the two means

# %%
α = 0.05
turnovers_playoff_values = train[train.playoffs == 1].trnovrs_commited
turnovers_nonplayoff_values = train[train.playoffs == 0].trnovrs_commited
t, p = stats.ttest_ind(turnovers_playoff_values,turnovers_nonplayoff_values,equal_var=True)
print(t,p,α)
print(f'p = {p:e}')
# Out:
# -3.6216098336890634 0.00031303633373320783 0.05
# p = 3.130363e-04

# %%
train.columns
# Out:
# Index(['fg_pct', 'opp_fg_pct', 'three_pt_pct', 'opp_three_pt_pct', 'ft_pct',
#        'rebounds', 'opp_rebounds', 'assists', 'steals', 'opp_steals',
#        'trnovrs_commited', 'pts', 'opp_pts', 'opp_fouls', 'prev_season',
#        'playoffs'],
#       dtype='object')

# %%
df_mean_by_playoffs = train.groupby(by='playoffs').mean()

# %%
df_mean_by_playoffs
# Out:
#             fg_pct  opp_fg_pct  three_pt_pct  opp_three_pt_pct    ft_pct  \
# playoffs
# 0         0.452672    0.469608      0.334898          0.347860  0.751404
# 1         0.470160    0.456940      0.337084          0.332584  0.760400
#
#            rebounds  opp_rebounds    assists    steals  opp_steals  \
# playoffs
# 0         44.038854     45.357962  23.221975  8.104777    8.474204
# 1         44.830144     44.026077  24.810048  8.523684    8.174402
#
#           trnovrs_commited         pts     opp_pts  opp_fouls  prev_season
# playoffs
# 0                16.217834  104.837261  108.976752  22.505732     0.305732
# 1                15.776316  108.600718  105.400239  23.288995     0.729665

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x=train.opp_pts, y=train.opp_fouls,hue=train.playoffs,ec='black',alpha=0.6)
plt.title('')
plt.show()

# %%
cols = ['assists','fg_pct','opp_fg_pct','three_pt_pct', 'opp_three_pt_pct','rebounds',
        'opp_rebounds','trnovrs_commited','opp_steals']
sns.pairplot(train[cols], corner=True,kind='reg')
plt.show()

# %%
# np.triu(train.corr())
fig = plt.figure(figsize=(12,5))
sns.heatmap(train.corr(),
           cmap='vlag',
           annot=True,
           mask=np.triu(train.corr(),1))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # rebounds and opp_fg_pct correlation?
# ## Does a statistically significant correlation exist between mean rebounds and opp_fg_pct within the OVERALL sample?
# ### Pearson's R
#
# ### Hypothesis
#
# - ${H_0}$: No statistically significant correlation exists between mean rebounds and opp_fg_pct.
# - ${H_a}$: A statistically significant correlation exists between mean rebounds and opp_fg_pct
# #### Pearson's R

# %%
α = 0.05

r, p = stats.pearsonr(train.rebounds,train.opp_fg_pct)
print(r,p,α)
print(f'p = {p:e}')

# %% [markdown]
# # with a p-value of close to Zero, Reject the NULL
# ### A statistically significant correlation exists, there is evidence to suggest that the two samples exhibit a linear relationship.
